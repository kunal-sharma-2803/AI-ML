# %% [raw]
# Matplotlib :- a python plotting lib
# Why matplotlib :- Built on numpy arrays (and python)
#                   Integrates directly with pandas with pandas api
#                   can create or advanced plots
#                   simple to use interface
#
# worksflow :-
# create data -> create plot (figure) -> plot data (axes on figure) -> customise plot -> save/share plot

# %%
# %matplotlib inline 
# matplotlib is in the notebook, i.e. figures should be shown here only
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot(); # generates the figure (plot)

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,12,13,14]
plt.plot(x,y);
# stateless way of plotting
# this is also called pyplot API, which is less flexible than object-oriented API
# look for lifecycle of a plot in matplotlib

# %%
# 1st method 
fig = plt.figure() # creates a figure
#plt.show();
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1]) 
ax.plot(x,y) # add some data
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,250]);
type(fig), type(ax)
#  this is object-oriented
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # Anatomy of a figure

# %% [markdown]
# <img src="anatomy-of-matplotlib.jpg">

# %% [markdown]
# # matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. prepare data
x = [1,2,3,4]
y = [11,22,33,11]

# 2. setup plot
fig, ax = plt.subplots()

# 3. plot data
ax.plot(x,y)

# 4. customise plot
ax.set(title="sample plot", xlabel="x-axis", ylabel="yaxis")

# 5. save & show (you save the whole figure)
fig.savefig("./matplotlib-plots/sample-plot.png")

# %% [markdown]
# # making figures with numpy arrays

# %%
import numpy as np

# %%
# create some data
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# plot the data, by default plot creates a line plot
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
# use the same data to create a scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
# another scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
nut_butter_prices = {"almond":10,"peanut":8,"cashew":12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="nut butter prices",xlabel="Type",ylabel="Price");

# %%
x = np.random.randint(1,10,size=(1,10))
y = np.random.randint(20,50,size=(1,10))

# %%
fig, ax = plt.subplots()
ax.scatter(x,y);

# %%
# make some data for histogram
x = np.random.randn(10000)
fig, ax = plt.subplots()
ax.hist(x);

# %%
# subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# sub plots 2
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
# same for other 2

# %% [markdown]
# # plotting form pandas dataframes

# %%
import pandas as pd

# %%
# make a dataframe
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range("23/03/2026",periods=1000))
ts = ts.cumsum() # cumulative sum
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Price = car_sales.Price.str.replace('$','')
car_sales.Price = car_sales.Price.str.replace(',','')
car_sales.Price = car_sales.Price.str.replace('.','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales.Price = car_sales.Price.str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Day"] = pd.date_range("24/03/2026",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price   Sale Day
# 0  Toyota  White         150043      4   4000 2026-03-24
# 1   Honda    Red          87899      4   5000 2026-03-25
# 2  Toyota   Blue          32549      3   7000 2026-03-26
# 3     BMW  Black          11179      5  22000 2026-03-27
# 4  Nissan  White         213095      4   3500 2026-03-28
# 5  Toyota  Green          99213      4   4500 2026-03-29
# 6   Honda   Blue          45698      4   7500 2026-03-30
# 7   Honda   Blue          54738      4   7000 2026-03-31
# 8  Toyota  White          60000      4   6250 2026-04-01
# 9  Nissan  White          31600      4   9700 2026-04-02

# %%
car_sales.Price = pd.to_numeric(car_sales.Price)

# %%
car_sales.Price.dtype
# Out:
# dtype('int64')

# %%
car_sales["total sales"] = car_sales.Price.cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price   Sale Day  total sales
# 0  Toyota  White         150043      4   4000 2026-03-24         4000
# 1   Honda    Red          87899      4   5000 2026-03-25         9000
# 2  Toyota   Blue          32549      3   7000 2026-03-26        16000
# 3     BMW  Black          11179      5  22000 2026-03-27        38000
# 4  Nissan  White         213095      4   3500 2026-03-28        41500
# 5  Toyota  Green          99213      4   4500 2026-03-29        46000
# 6   Honda   Blue          45698      4   7500 2026-03-30        53500
# 7   Honda   Blue          54738      4   7000 2026-03-31        60500
# 8  Toyota  White          60000      4   6250 2026-04-01        66750
# 9  Nissan  White          31600      4   9700 2026-04-02        76450

# %%
car_sales.plot(x="Sale Day",y="total sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# how about a bar graph 
x = np.random.rand(10,5)

df = pd.DataFrame(x,columns=['a','b','c','d','e'])
df
# Out:
#           a         b         c         d         e
# 0  0.428830  0.823184  0.828664  0.335487  0.242892
# 1  0.422931  0.392107  0.232123  0.176756  0.247514
# 2  0.183773  0.566887  0.604118  0.845856  0.098259
# 3  0.354874  0.322082  0.778939  0.564433  0.753168
# 4  0.678420  0.672522  0.546541  0.239061  0.924073
# 5  0.455461  0.860087  0.745980  0.199455  0.394225
# 6  0.763594  0.597858  0.166417  0.648984  0.947168
# 7  0.390695  0.562272  0.848951  0.593306  0.740531
# 8  0.123097  0.028644  0.144387  0.631647  0.459810
# 9  0.052795  0.276170  0.713351  0.722549  0.339096

# %%
# 1st way
df.plot.bar();

# %%
# 2nd way
df.plot(kind="bar");

# %%
car_sales.plot.barh(x="Make", y="Odometer (KM)");

# %%
# how about histograms

car_sales["Odometer (KM)"].plot.hist();

# %%
# histogram divides the data into bins be default there are 10 bins 
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
car_sales.plot.hist(figsize=(10,30),subplots=True);

# %%
# here the problem is that same scale is used in x axis

# %% [markdown]
# ### which one to use among pyplot vs matplotlib oo method
# -- when plotting something quickly then pyplot
# -- when plotting something advanced then oo method

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease.age>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# this is the pyplot method
over_50.plot.scatter(x='age',y='chol',c='target');

# %%
# this is the oo method mixed with pyplot
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',x='age',y='chol',c='target',ax=ax);
# ax.set_xlim([45,100]); # to set limits of x axis

# %%
# oo method from scratch
fig, ax = plt.subplots(figsize=(10,6));
scatter = ax.scatter(x=over_50.age,y=over_50.chol,c=over_50.target);
ax.set(title="heart disease",xlabel="age",ylabel="cholestrol");
ax.legend(*scatter.legend_elements(),title="Target");
ax.axhline(over_50.chol.mean(),linestyle="-.");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# sub plot of chol,age,thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(10,10));
# we can add ,sharex=True there to share the x axis

# working on ax0
scatter = ax0.scatter(x=over_50.age,y=over_50.chol,c=over_50.target);
ax0.set(title="heart disease",xlabel="age",ylabel="cholestrol");
ax0.legend(*scatter.legend_elements(),title="Target");
ax0.axhline(over_50.chol.mean(),linestyle="-.");

scatter = ax1.scatter(x=over_50.age,y=over_50.thalach,c=over_50.target);
ax1.set(title="heart disease 2",xlabel="age",ylabel="thalach level");
ax1.legend(*scatter.legend_elements(),title="Target");
ax1.axhline(over_50.thalach.mean(),linestyle="-.");

fig.suptitle("heart disease analysis",fontsize=14,fontweight="bold");
