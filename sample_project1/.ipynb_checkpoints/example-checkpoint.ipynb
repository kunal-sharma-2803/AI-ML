# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # hello
# here we are testing how to work with jupyter

# %%
1+1
# Out:
# 2

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is BA92-9EA7
#
#  Directory of C:\Users\kunal\Desktop\AI_ML\sample_project1
#
# 04-Mar-26  09:35 PM    <DIR>          .
# 04-Mar-26  08:53 PM    <DIR>          ..
# 04-Mar-26  09:27 PM    <DIR>          .ipynb_checkpoints
# 04-Mar-26  07:36 PM    <DIR>          env
# 04-Mar-26  09:35 PM             1,446 example.ipynb
# 04-Mar-26  08:36 PM             5,037 Untitled.ipynb
#                2 File(s)          6,483 bytes
#                4 Dir(s)  90,311,684,096 bytes free

# %%
ls -la
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is BA92-9EA7
#
#  Directory of C:\Users\kunal\Desktop\AI_ML\sample_project1
# File Not Found

# %%
# !ls -la
# Out:
# total 44
# drwxr-xr-x 1 kunal 197121    0 Mar  4 21:35 .
# drwxr-xr-x 1 kunal 197121    0 Mar  4 20:53 ..
# drwxr-xr-x 1 kunal 197121    0 Mar  4 21:27 .ipynb_checkpoints
# -rw-r--r-- 1 kunal 197121 5037 Mar  4 20:36 Untitled.ipynb
# drwxr-xr-x 1 kunal 197121    0 Mar  4 19:36 env
# -rw-r--r-- 1 kunal 197121 1446 Mar  4 21:35 example.ipynb

# %%
pwd
# Out:
# 'C:\\Users\\kunal\\Desktop\\AI_ML\\sample_project1'

# %%
whoami
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 whoami
#
# NameError: name 'whoami' is not defined

# %%
# !whoami
# Out:
# vivobook\kunal

# %%
# !clear
