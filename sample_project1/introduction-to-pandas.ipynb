# %%
import pandas as pd

# %% [markdown]
# # 2 main types

# %% [markdown]
# series = 1 dimentional

# %%
series = pd.series(["BMW","Mercedes","Audi"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 series = pd.series(["BMW","Mercedes","Audi"])
#
# AttributeError: module 'pandas' has no attribute 'series'

# %% [markdown]
# "S" should be capital

# %%
series = pd.Series(["BMW","Mercedes","Audi"])

# %%
series
# Out:
# 0         BMW
# 1    Mercedes
# 2        Audi
# dtype: str

# %%
colors = pd.Series(["Red","Yellow","Green"])
colors
# Out:
# 0       Red
# 1    Yellow
# 2     Green
# dtype: str

# %% [markdown]
# dataframe = 2 dimentional

# %%
car_data = pd.DataFrame({"Car_Brand":series, "Color":colors})
car_data
# Out:
#   Car_Brand   Color
# 0       BMW     Red
# 1  Mercedes  Yellow
# 2      Audi   Green

# %%
#import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# axis = 0 means row
# axis = 1 means column

# %%
# exporting a dataframe
car_sales.to_csv("exported-car-sales.csv")

# %% [markdown]
# we can add a parameter (..... , index=False)
# this will not export the first index column

# %%
car_sales.to_csv("exported-car-sales-without-index.csv",index=False)

# %% [markdown]
# # Describe Data

# %%
# this is an attribute = some metadata about car-sales
car_sales.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %% [markdown]
# car_sales.to_csv()
# this is a function = it does some action

# %%
car_columns = car_sales.columns
car_columns
# this is a list
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# some functions

# %%
car_sales.describe()
# works on only numeric columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
car_sales.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 car_sales.mean()
#
# File ~\Desktop\AI_ML\sample_project1\env\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\Desktop\AI_ML\sample_project1\env\Lib\site-packages\pandas\core\frame.py:14461, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14380 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14381 def mean(
#   14382     self,
#    (...)  14386     **kwargs,
# ...

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# for a single row

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# np.float64(78601.4)

# %%
len(car_sales)
#number of rows
# Out:
# 10

# %% [markdown]
# # Viewing and Selecting data

# %%
car_sales.head()
# top 5 rows of the data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
# so we manipulate the data and then call head function to view the changes

# %%
car_sales.tail(7)
# tail is also 5 by default, both head and tail can have arguments also
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# .loc i.e. location
animals = pd.Series(["panda","cat","dog","lion","tiger"],index=[10,5,9,3,3])
animals
# the series will be created with the index we gave it
# Out:
# 10    panda
# 5       cat
# 9       dog
# 3      lion
# 3     tiger
# dtype: str

# %%
animals.loc[10]
# Out:
# 'panda'

# %%
animals.loc[3]
# Out:
# 3     lion
# 3    tiger
# dtype: str

# %%
# .iloc i.e. position
animals
# Out:
# 10    panda
# 5       cat
# 9       dog
# 3      lion
# 3     tiger
# dtype: str

# %%
animals.iloc[0]
# Out:
# 'panda'

# %%
animals.iloc[2]
# Out:
# 'dog'

# %%
# slicing is also available in iloc
animals.iloc[:3]
# Out:
# 10    panda
# 5       cat
# 9       dog
# dtype: str

# %%
# loc returns the location till that index
animals.loc[:5]
# Out:
# 10    panda
# 5       cat
# dtype: str
